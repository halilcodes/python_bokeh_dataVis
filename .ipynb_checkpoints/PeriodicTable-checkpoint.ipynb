# %%
#Importing libraries
from bokeh.plotting import figure
from bokeh.io import output_file, show
from bokeh.sampledata.periodic_table import elements
from bokeh.models import Range1d, PanTool, ResetTool, HoverTool, ColumnDataSource, LabelSet

# %%
elements = elements.dropna()

# %%
elements
# Out:
#     atomic number symbol        name  atomic mass      CPK  \
# 2               3     Li     Lithium        6.941  #CC80FF
# 5               6      C      Carbon      12.0107  #909090
# 6               7      N    Nitrogen      14.0067  #3050F8
# 7               8      O      Oxygen      15.9994  #FF0D0D
# 8               9      F    Fluorine   18.9984032  #90E050
# 10             11     Na      Sodium  22.98976928  #AB5CF2
# 11             12     Mg   Magnesium      24.3050  #8AFF00
# 13             14     Si     Silicon      28.0855  #F0C8A0
# 14             15      P  Phosphorus    30.973762  #FF8000
# 15             16      S      Sulfur       32.065  #FFFF30
# 16             17     Cl    Chlorine       35.453  #1FF01F
# 18             19      K   Potassium      39.0983  #8F40D4
# 27             28     Ni      Nickel      58.6934  #50D050
# 28             29     Cu      Copper       63.546  #C88033
# 29             30     Zn        Zinc        65.38  #7D80B0
# 30             31     Ga     Gallium       69.723  #C28F8F
# 32             33     As     Arsenic     74.92160  #BD80E3
# 33             34     Se    Selenium        78.96  #FFA100
# 34             35     Br     Bromine       79.904  #A62929
# 45             46     Pd   Palladium       106.42  #006985
# 46             47     Ag      Silver     107.8682  #C0C0C0
# 47             48     Cd     Cadmium      112.411  #FFD98F
# 48             49     In      Indium      114.818  #A67573
# 49             50     Sn         Tin      118.710  #668080
# 51             52     Te   Tellurium       127.60  #D47A00
# 52             53      I      Iodine    126.90447  #940094
# 77             78     Pt    Platinum      195.084  #D0D0E0
# 78             79     Au        Gold   196.966569  #FFD123
# 79             80     Hg     Mercury       200.59  #B8B8D0
# 80             81     Tl    Thallium     204.3833  #A6544D
# 81             82     Pb        Lead        207.2  #575961
#
#    electronic configuration  electronegativity  atomic radius ion radius  \
# 2                  [He] 2s1               0.98          134.0    76 (+1)
# 5              [He] 2s2 2p2               2.55           77.0    16 (+4)
# 6              [He] 2s2 2p3               3.04           75.0   146 (-3)
# 7              [He] 2s2 2p4               3.44           73.0   140 (-2)
# 8              [He] 2s2 2p5               3.98           71.0   133 (-1)
# 10                 [Ne] 3s1               0.93          154.0   102 (+1)
# 11                 [Ne] 3s2               1.31          130.0    72 (+2)
# 13             [Ne] 3s2 3p2               1.90          111.0    40 (+4)
# 14             [Ne] 3s2 3p3               2.19          106.0    44 (+3)
# 15             [Ne] 3s2 3p4               2.58          102.0   184 (-2)
# 16             [Ne] 3s2 3p5               3.16           99.0   181 (-1)
# 18                 [Ar] 4s1               0.82          196.0   138 (+1)
# 27             [Ar] 3d8 4s2               1.91          121.0    69 (+2)
# 28            [Ar] 3d10 4s1               1.90          138.0    77 (+1)
# 29            [Ar] 3d10 4s2               1.65          131.0    74 (+2)
# 30        [Ar] 3d10 4s2 4p1               1.81          126.0    62 (+3)
# 32        [Ar] 3d10 4s2 4p3               2.18          119.0    58 (+3)
# 33        [Ar] 3d10 4s2 4p4               2.55          116.0   198 (-2)
# 34        [Ar] 3d10 4s2 4p5               2.96          114.0   196 (-1)
# 45                [Kr] 4d10               2.20          131.0    59 (+1)
# 46            [Kr] 4d10 5s1               1.93          153.0   115 (+1)
# 47            [Kr] 4d10 5s2               1.69          148.0    95 (+2)
# 48        [Kr] 4d10 5s2 5p1               1.78          144.0    80 (+3)
# 49        [Kr] 4d10 5s2 5p2               1.96          141.0   112 (+2)
# 51        [Kr] 4d10 5s2 5p4               2.10          135.0   221 (-2)
# 52        [Kr] 4d10 5s2 5p5               2.66          133.0   220 (-1)
# 77        [Xe] 4f14 5d9 6s1               2.28          128.0    86 (+2)
# 78       [Xe] 4f14 5d10 6s1               2.54          144.0   137 (+1)
# 79       [Xe] 4f14 5d10 6s2               2.00          149.0   119 (+1)
# 80   [Xe] 4f14 5d10 6s2 6p1               2.04          148.0   150 (+1)
# 81   [Xe] 4f14 5d10 6s2 6p2               2.33          147.0   119 (+2)
#
#     van der Waals radius  ...     EA  standard state      bonding type  \
# 2                  182.0  ...  -60.0           solid          metallic
# 5                  170.0  ... -154.0           solid  covalent network
# 6                  155.0  ...   -7.0             gas          diatomic
# 7                  152.0  ... -141.0             gas          diatomic
# 8                  147.0  ... -328.0             gas            atomic
# 10                 227.0  ...  -53.0           solid          metallic
# 11                 173.0  ...    0.0           solid          metallic
# 13                 210.0  ... -134.0           solid          metallic
# 14                 180.0  ...  -72.0           solid  covalent network
# 15                 180.0  ... -200.0           solid  covalent network
# 16                 175.0  ... -349.0             gas  covalent network
# 18                 275.0  ...  -48.0           solid          metallic
# 27                 163.0  ... -112.0           solid          metallic
# 28                 140.0  ... -118.0           solid          metallic
# 29                 139.0  ...    0.0           solid          metallic
# 30                 187.0  ...  -29.0           solid          metallic
# 32                 185.0  ...  -78.0           solid          metallic
# 33                 190.0  ... -195.0           solid          metallic
# 34                 185.0  ... -325.0          liquid  covalent network
# 45                 163.0  ...  -54.0           solid          metallic
# 46                 172.0  ... -126.0           solid          metallic
# 47                 158.0  ...    0.0           solid          metallic
# 48                 193.0  ...  -29.0           solid          metallic
# 49                 217.0  ... -107.0           solid          metallic
# 51                 206.0  ... -190.0           solid          metallic
# 52                 198.0  ... -295.0           solid  covalent network
# 77                 175.0  ... -205.0           solid          metallic
# 78                 166.0  ... -223.0           solid          metallic
# 79                 155.0  ...    0.0          liquid          metallic
# 80                 196.0  ...  -19.0           solid          metallic
# 81                 202.0  ...  -35.0           solid          metallic
#
#    melting point  boiling point  density                 metal  \
# 2          454.0         1615.0     0.54          alkali metal
# 5         3823.0         4300.0     2.26              nonmetal
# 6           63.0           77.0     0.00              nonmetal
# 7           55.0           90.0     0.00              nonmetal
# 8           54.0           85.0     0.00               halogen
# 10         371.0         1156.0     0.97          alkali metal
# 11         923.0         1363.0     1.74  alkaline earth metal
# 13        1687.0         3173.0     2.33             metalloid
# 14         317.0          554.0     1.82              nonmetal
# 15         388.0          718.0     1.96              nonmetal
# 16         172.0          239.0     0.00               halogen
# 18         337.0         1032.0     0.86          alkali metal
# 27        1728.0         3186.0     8.91      transition metal
# 28        1358.0         3200.0     8.92      transition metal
# 29         693.0         1180.0     7.14      transition metal
# 30         303.0         2477.0     5.90                 metal
# 32        1090.0          887.0     5.73             metalloid
# 33         494.0          958.0     4.82              nonmetal
# 34         266.0          332.0     3.12               halogen
# 45        1828.0         3236.0    12.02      transition metal
# 46        1235.0         2435.0    10.49      transition metal
# 47         594.0         1040.0     8.65      transition metal
# 48         430.0         2345.0     7.31                 metal
# 49         505.0         2875.0     7.31                 metal
# 51         723.0         1261.0     6.24             metalloid
# 52         387.0          457.0     4.94               halogen
# 77        2041.0         4098.0    21.09      transition metal
# 78        1337.0         3129.0    19.30      transition metal
# 79         234.0          630.0    13.53      transition metal
# 80         577.0         1746.0    11.85                 metal
# 81         601.0         2022.0    11.34                 metal
#
#    year discovered group period
# 2             1817     1      2
# 5          Ancient    14      2
# 6             1772    15      2
# 7             1774    16      2
# 8             1670    17      2
# 10            1807     1      3
# 11            1808     2      3
# 13            1854    14      3
# 14            1669    15      3
# 15         Ancient    16      3
# 16            1774    17      3
# 18            1807     1      4
# 27            1751    10      4
# 28         Ancient    11      4
# 29            1746    12      4
# 30            1875    13      4
# 32         Ancient    15      4
# 33            1817    16      4
# 34            1826    17      4
# 45            1803    10      5
# 46         Ancient    11      5
# 47            1817    12      5
# 48            1863    13      5
# 49         Ancient    14      5
# 51            1782    16      5
# 52            1811    17      5
# 77         Ancient    10      6
# 78         Ancient    11      6
# 79         Ancient    12      6
# 80            1861    13      6
# 81         Ancient    14      6
#
# [31 rows x 21 columns]

# %%
elements.columns
# Out:
# Index(['atomic number', 'symbol', 'name', 'atomic mass', 'CPK',
#        'electronic configuration', 'electronegativity', 'atomic radius',
#        'ion radius', 'van der Waals radius', 'IE-1', 'EA', 'standard state',
#        'bonding type', 'melting point', 'boiling point', 'density', 'metal',
#        'year discovered', 'group', 'period'],
#       dtype='object')

# %%
colormap = {
    "gas": "yellow",
    "liquid": "orange",
    "solid": "red"
}
elements['color'] = [colormap[i] for i in elements['standard state']]
# Out:
# 31

# %%
elements['size'] = elements['van der Waals radius'] / 10
# Out:
# C:\Users\halil\AppData\Local\Temp\ipykernel_18004\4125411261.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elements['size'] = elements['van der Waals radius'] / 10

# %%
elements.head()
# Out:
#    atomic number symbol      name atomic mass      CPK  \
# 2              3     Li   Lithium       6.941  #CC80FF
# 5              6      C    Carbon     12.0107  #909090
# 6              7      N  Nitrogen     14.0067  #3050F8
# 7              8      O    Oxygen     15.9994  #FF0D0D
# 8              9      F  Fluorine  18.9984032  #90E050
#
#   electronic configuration  electronegativity  atomic radius ion radius  \
# 2                 [He] 2s1               0.98          134.0    76 (+1)
# 5             [He] 2s2 2p2               2.55           77.0    16 (+4)
# 6             [He] 2s2 2p3               3.04           75.0   146 (-3)
# 7             [He] 2s2 2p4               3.44           73.0   140 (-2)
# 8             [He] 2s2 2p5               3.98           71.0   133 (-1)
#
#    van der Waals radius  ...      bonding type  melting point boiling point  \
# 2                 182.0  ...          metallic          454.0        1615.0
# 5                 170.0  ...  covalent network         3823.0        4300.0
# 6                 155.0  ...          diatomic           63.0          77.0
# 7                 152.0  ...          diatomic           55.0          90.0
# 8                 147.0  ...            atomic           54.0          85.0
#
#   density         metal  year discovered  group period   color  size
# 2    0.54  alkali metal             1817      1      2     red  18.2
# 5    2.26      nonmetal          Ancient     14      2     red  17.0
# 6    0.00      nonmetal             1772     15      2  yellow  15.5
# 7    0.00      nonmetal             1774     16      2  yellow  15.2
# 8    0.00       halogen             1670     17      2  yellow  14.7
#
# [5 rows x 23 columns]

# %%
gas = ColumnDataSource(elements[elements['standard state'] == 'gas'])
liquid = ColumnDataSource(elements[elements['standard state'] == 'liquid'])
solid = ColumnDataSource(elements[elements['standard state'] == 'solid'])

#Define the output file path
output_file("periodic.html")

#Create the figure object
f = figure()

#adding glyphs

f.circle(x='atomic radius', y='boiling point', size='size', fill_alpha=0.2, 
         color="color", line_dash='dotted', legend_label='Gas', source=gas)

f.circle(x='atomic radius', y='boiling point', size='size', fill_alpha=0.2, 
        color="color", line_dash='dotted', legend_label='Liquid', source=liquid)

f.circle(x='atomic radius', y='boiling point', size='size', fill_alpha=0.2,
        color="color", line_dash='dotted', legend_label='Solid', source=solid)

# f.legend.location = "top_left"
f.xaxis.axis_label = "Atomic Radius"
f.yaxis.axis_label = "Boiling Point"

#Save and show the figure
show(f)
